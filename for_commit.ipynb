# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Colab Notebooks/STUDY_AI

# %%
# !git add .

# %%
  # !git config --global user.email "yhyuntak@gmail.com"
  # !git config --global user.name "yhyuntak"

# %%
# !git commit -m "update commit ipynb"

# %%
# !git remote set-url origin https://yhyuntak:0164532ht!@github.com/yhyuntak/STUDY_AI.git

# %%
# !git push
